# %%
import xarray as xr
import numpy as np
import warnings
import matplotlib.pyplot as plt
from scipy.signal import butter, sosfiltfilt
import matplotlib.animation as animation
from fastjmd95 import rho
import sys
warnings.filterwarnings("ignore")

dsState = xr.open_dataset('TPOSE6_Hourly_Oct2012.nc',engine='netcdf4')
sigma_0 = (rho(dsState.SALT, dsState.THETA, 0)-1000)

# %%
fig, ax = plt.subplots(figsize=(6, 5))
dsState.VVEL.sel(lat=[2.25],lon=[140.0],method='nearest').sel(time=slice(280,600)).plot(ax=ax)
ax.plot([300,400],[-600,-400])
ax.plot([500,600],[-600,-400])

# %%
dsState.VVEL.sel(lat=[2.25],lon=[140.0],method='nearest').plot()
((dsState.THETA*12).sel(z=[0],lat=[2.25],lon=[140.0],method='nearest')-500).plot()

# %%
fig, ax = plt.subplots(figsize=(10, 5),ncols=2)
dsState.UVEL.sel(lon=[140.0],lat=[1.0],method='nearest').plot(ax=ax[0])
ax[0].axvline(450,color='k')

dsState.UVEL.sel(lon=[140.0],method='nearest').sel(time=435).plot(ax=ax[1])

# %%
fig, ax = plt.subplots(figsize=(10, 5))
dsState.THETA.sel(z=[0.0],method='nearest').sel(time=435).plot(ax=ax, cmap='jet')
ax.axvline(220,color='k')
